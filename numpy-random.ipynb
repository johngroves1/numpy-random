# %% [markdown]
# # The Numpy Random Package
#
# [Official documentaion](https://numpy.org/doc/stable/reference/random/index.html)
#
# ***

# %%
# Efficient numerical arrays.
import numpy as np
# Plotting.
import matplotlib.pyplot as plt

# %%
# Change default style sheet.
plt.style.use('fivethirtyeight')

# Change the default figure size.
plt.rcParams['figure.figsize'] = [12, 6]

# %% [markdown]
# <br>
#
# ## numpy.random.normal
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
#
# ***

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# %%
# Look at the first ten items.
s[:10]
# Out:
# array([-0.00685536,  0.18030129, -0.04090013, -0.12718149,  0.02705938,
#         0.1127128 , -0.05415105,  0.07506633, -0.18002094,  0.08246794])

# %%
abs(mu - np.mean(s))
# Out:
# 0.0008136580427575164

# %%
abs(sigma - np.std(s, ddof=1))
# Out:
# 0.0008979570942192067

# %%
count, bins, ignored = plt.hist(s, 30, density=True)
f = 1/(sigma * np.sqrt(2 * np.pi)) * np.exp(-(bins - mu)**2 /(2 * sigma**2))
plt.plot(bins,  f, linewidth=2)
plt.show()

# %% [markdown]
# ## References
#  https://www.datacamp.com/community/tutorials/numpy-random

# %% [markdown]
# ***
#
# # End
